# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')
df_xlsx = pd.read_excel('pokemon_data.xlsx')
df_txt = pd.read_csv('pokemon_data.txt', delimiter="\t")

# %%
print(df.tail(3))
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
print(df_xlsx.head(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
print(df_txt.tail(3))
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
## Reading Headers
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
##Read each column
print(df[['Name', 'Type 1', 'Type 2']][0:13])
# Out:
#                          Name Type 1  Type 2
# 0                   Bulbasaur  Grass  Poison
# 1                     Ivysaur  Grass  Poison
# 2                    Venusaur  Grass  Poison
# 3       VenusaurMega Venusaur  Grass  Poison
# 4                  Charmander   Fire     NaN
# 5                  Charmeleon   Fire     NaN
# 6                   Charizard   Fire  Flying
# 7   CharizardMega Charizard X   Fire  Dragon
# 8   CharizardMega Charizard Y   Fire  Flying
# 9                    Squirtle  Water     NaN
# 10                  Wartortle  Water     NaN
# 11                  Blastoise  Water     NaN
# 12    BlastoiseMega Blastoise  Water     NaN

# %%
##Print Each Row
#print(df.iloc[1])
df.loc[df['Type 1'] == 'Grass'][0:10]
# Out:
#      #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49       65
# 1    2                Ivysaur  Grass  Poison  60      62       63       80
# 2    3               Venusaur  Grass  Poison  80      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 48  43                 Oddish  Grass  Poison  45      50       55       75
# 49  44                  Gloom  Grass  Poison  60      65       70       85
# 50  45              Vileplume  Grass  Poison  75      80       85      110
# 75  69             Bellsprout  Grass  Poison  50      75       35       70
# 76  70             Weepinbell  Grass  Poison  65      90       50       85
# 77  71             Victreebel  Grass  Poison  80     105       65      100
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# ...

# %%
##Print A Specific Position
print(df.iloc[4, 1])
# Out:
# Charmander

# %%
###Sorting and describing data

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values(['Type 1', 'HP'], ascending=[1, False])[0:10]
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# 734  666                 Vivillon    Bug    Flying  80      52       50
# 447  402               Kricketune    Bug       NaN  77      85       51
# 220  205               Forretress    Bug     Steel  75      90      140
# 602  542                 Leavanny    Bug     Grass  75     103       80
# 717  649                 Genesect    Bug     Steel  71     120       95
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 520      116       56     95           4      False
# 698      135      105    100           5      False
# ...

# %%
### Making Changes to data

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
60 + 62 + 63 + 80 + 80 + 60
# Out:
# 405

# %%
df = df.drop(columns = ['Total'])

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1)

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
cols = list(df.columns)

df = df[cols[:4] + [cols[-1]] + cols[4:-1]]

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
### Saving Data To CSV

# %%
df.to_csv('modified.csv', index=0)

# %%
df.to_excel('modified.xlsx', index=0)

# %%
df.to_csv('modified.txt', index=0, sep='\t')

# %%
### Filtering Data

# %%
new_df = df.loc[( (df['Type 1'] == 'Bug') | (df['Type 2'] == 'Flying') ) & (df['HP'] >= 70)]

new_df.reset_index(drop=True, inplace=True)

new_df[0:10]
# Out:
#      #                       Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    6                  Charizard    Fire  Flying    534  78      84       78
# 1    6  CharizardMega Charizard Y    Fire  Flying    634  78     104       78
# 2   18                    Pidgeot  Normal  Flying    479  83      80       75
# 3   18        PidgeotMega Pidgeot  Normal  Flying    579  83      80       80
# 4   42                     Golbat  Poison  Flying    455  75      80       70
# 5   49                   Venomoth     Bug  Poison    450  70      65       60
# 6  123                    Scyther     Bug  Flying    500  70     110       80
# 7  130                   Gyarados   Water  Flying    540  95     125       79
# 8  142                 Aerodactyl    Rock  Flying    515  80     105       65
# 9  142  AerodactylMega Aerodactyl    Rock  Flying    615  80     135       85
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      109       85    100           1      False
# ...

# %%
new_df.to_csv('filtered.csv')

# %%
df.loc[~df['Name'].str.contains('Mega ')][0:10]
# Out:
#      #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0    1   Bulbasaur  Grass  Poison    318  45      49       49       65
# 1    2     Ivysaur  Grass  Poison    405  60      62       63       80
# 2    3    Venusaur  Grass  Poison    525  80      82       83      100
# 4    4  Charmander   Fire     NaN    309  39      52       43       60
# 5    5  Charmeleon   Fire     NaN    405  58      64       58       80
# 6    6   Charizard   Fire  Flying    534  78      84       78      109
# 9    7    Squirtle  Water     NaN    314  44      48       65       50
# 10   8   Wartortle  Water     NaN    405  59      63       80       65
# 11   9   Blastoise  Water     NaN    530  79      83      100       85
# 13  10    Caterpie    Bug     NaN    195  45      30       35       20
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# ...

# %%
import re

df.loc[df['Type 1'].str.contains('fire|GrasS', flags=re.I, regex=True)][0:10]
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 42  37                     Vulpix   Fire     NaN    299  38      41       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       65     45           1      False
# ...

# %%
df.loc[df['Name'].str.contains('^Pi[a-z]*', flags=re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying    251   40      45
# 21    17            Pidgeotto    Normal    Flying    349   63      60
# 22    18              Pidgeot    Normal    Flying    479   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 30    25              Pikachu  Electric       NaN    320   35      55
# 136  127               Pinsir       Bug       NaN    500   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying    600   65     155
# 186  172                Pichu  Electric       NaN    205   20      40
# 219  204               Pineco       Bug       NaN    290   50      65
# 239  221            Piloswine       Ice    Ground    450  100     100
# 438  393               Piplup     Water       NaN    314   53      51
# 558  499              Pignite      Fire  Fighting    418   90      93
# ...

# %%
### Conditional Changes

# %%
df.loc[df['Type 1'] == 'Ground', 'Type 1'] = 'Earth'

df.loc[df['Type 1'] == 'Earth'][0:10]
# Out:
#        #       Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 32    27  Sandshrew  Earth     NaN    300   50      75       85       20
# 33    28  Sandslash  Earth     NaN    450   75     100      110       45
# 55    50    Diglett  Earth     NaN    265   10      55       25       35
# 56    51    Dugtrio  Earth     NaN    405   35      80       50       50
# 112  104     Cubone  Earth     NaN    320   50      50       95       40
# 113  105    Marowak  Earth     NaN    425   60      80      110       50
# 119  111    Rhyhorn  Earth    Rock    345   80      85       95       30
# 120  112     Rhydon  Earth    Rock    485  105     130      120       45
# 222  207     Gligar  Earth  Flying    430   65      75      105       35
# 250  231     Phanpy  Earth     NaN    330   90      60       60       40
#
#      Sp. Def  Speed  Generation  Legendary
# 32        30     40           1      False
# 33        55     65           1      False
# ...

# %%
df.loc[df['Type 1'] == 'Dragon', 'Legendary'] = True

df.loc[df['Type 1'] == 'Dragon'][0:10]
# Out:
#        #                     Name  Type 1   Type 2  Total  HP  Attack  \
# 159  147                  Dratini  Dragon      NaN    300  41      64
# 160  148                Dragonair  Dragon      NaN    420  61      84
# 161  149                Dragonite  Dragon   Flying    600  91     134
# 365  334                  Altaria  Dragon   Flying    490  75      70
# 366  334      AltariaMega Altaria  Dragon    Fairy    590  75     110
# 406  371                    Bagon  Dragon      NaN    300  45      75
# 407  372                  Shelgon  Dragon      NaN    420  65      95
# 408  373                Salamence  Dragon   Flying    600  95     135
# 409  373  SalamenceMega Salamence  Dragon   Flying    700  95     145
# 417  380                   Latias  Dragon  Psychic    600  80      80
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 159       45       50       50     50           1       True
# 160       65       70       70     70           1       True
# ...

# %%
df = pd.read_csv('pokemon_data.csv')
df['Total'] = df.iloc[:, 4:10].sum(axis=1)

df.loc[df['Type 1'] == 'Dragon'][0:10]
# Out:
#        #                     Name  Type 1   Type 2  HP  Attack  Defense  \
# 159  147                  Dratini  Dragon      NaN  41      64       45
# 160  148                Dragonair  Dragon      NaN  61      84       65
# 161  149                Dragonite  Dragon   Flying  91     134       95
# 365  334                  Altaria  Dragon   Flying  75      70       90
# 366  334      AltariaMega Altaria  Dragon    Fairy  75     110      110
# 406  371                    Bagon  Dragon      NaN  45      75       60
# 407  372                  Shelgon  Dragon      NaN  65      95      100
# 408  373                Salamence  Dragon   Flying  95     135       80
# 409  373  SalamenceMega Salamence  Dragon   Flying  95     145      130
# 417  380                   Latias  Dragon  Psychic  80      80       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 159       50       50     50           1      False    300
# ...

# %%
### Conditional Changes

# %%
df.loc[df['Total'] > 500, ['Generation','Legendary']] = ('Boomer', 'Cool Dude')

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation  Legendary  Total
# 0         65       65     45          1      False    318
# ...

# %%
### Aggregate Statistics (Group By)

# %%
df = pd.read_csv('modified.csv')

df[0:10]
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
df.groupby('Type 1').mean().sort_values('Speed', ascending=0)
# Out:
# C:\Users\quest\AppData\Local\Temp\ipykernel_20348\1311796646.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Type 1').mean().sort_values('Speed', ascending=0)
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# ...

# %%
df['Count'] = 1
df.groupby(['Type 1']).count()['Count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: Count, dtype: int64

# %%
df.groupby(['Type 1', 'Type 2']).count()['Count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: Count, Length: 136, dtype: int64

# %%
### Working with large Data Sets

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('modified.csv', chunksize=5):
    results = df.groupby(['Type 1', 'Type 2']).count()
    
    new_df = pd.concat([new_df, results])

# %%
new_df[:20]
# Out:
#                    # Name Type 1 Type 2 Total HP Attack Defense Sp. Atk  \
# (Grass, Poison)    4    4    NaN    NaN     4  4      4       4       4
# (Fire, Dragon)     1    1    NaN    NaN     1  1      1       1       1
# (Fire, Flying)     2    2    NaN    NaN     2  2      2       2       2
# (Bug, Flying)      1    1    NaN    NaN     1  1      1       1       1
# (Bug, Poison)      4    4    NaN    NaN     4  4      4       4       4
# (Normal, Flying)   4    4    NaN    NaN     4  4      4       4       4
# (Normal, Flying)   2    2    NaN    NaN     2  2      2       2       2
# (Poison, Ground)   2    2    NaN    NaN     2  2      2       2       2
# (Normal, Fairy)    1    1    NaN    NaN     1  1      1       1       1
# (Grass, Poison)    2    2    NaN    NaN     2  2      2       2       2
# (Normal, Fairy)    1    1    NaN    NaN     1  1      1       1       1
# (Poison, Flying)   2    2    NaN    NaN     2  2      2       2       2
# ...
